# %% [markdown]
# Read the output of my Pythia test (written in C++), and draw a hist. Hopefully this matches when taus were read out of .hepmc file from python.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pT_tau.txt", header=None, names=['pT'])

# %%
plt.hist(df['pT'], bins=30)
plt.yscale('log')
plt.title('pT of TAUS in some unweighted_events.lhe (from MONOTAU)')
plt.show()
