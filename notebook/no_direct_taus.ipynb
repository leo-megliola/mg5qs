# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import concurrent.futures
import pickle
import mg5qs_import as qs

# %%
MG5_PATH = Path(os.getenv('MG5QS_MG5_PATH'))      
INPUT_PATH = Path(os.getenv('MG5QS_INPUT_PATH')) 
qs.edit_card_spec(INPUT_PATH / 'proc_card_bg_notau.dat')
# Out:
# #************************************************************
# #*                        MadGraph 5                        *
# #*                                                          *
# #*                *                       *                 *
# #*                  *        * *        *                   *
# #*                    * * * * 5 * * * *                     *
# #*                  *        * *        *                   *
# #*                *                       *                 *
# #*                                                          *
# #*                                                          *
# #*    The MadGraph Development Team - Please visit us at    *
# #*    https://server06.fynu.ucl.ac.be/projects/madgraph     *
# #*                                                          *
# #************************************************************
# #*                                                          *
# ...

# %%
output_name, FRAMEWORK_PATH = qs.run_MG5(qs.MG5_PATH, qs.INPUT_PATH, proc_card_name='proc_card_bg_notau.dat')
output_name, FRAMEWORK_PATH
# Out:
# ('NO_DIRECT_TAU', PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU'))

# %%
qs.edit_card(FRAMEWORK_PATH)
# Out:
# #*********************************************************************
# #                       MadGraph5_aMC@NLO                            *
# #                                                                    *
# #                     run_card.dat MadEvent                          *
# #                                                                    *
# #  This file is used to set the parameters of the run.               *
# #                                                                    *
# #  Some notation/conventions:                                        *
# #                                                                    *
# #   Lines starting with a '# ' are info or comments                  *
# #                                                                    *
# #   mind the format:   value    = variable     ! comment             *
# #                                                                    *
# ...

# %%
card = qs.ParamCard(FRAMEWORK_PATH / 'Cards' / 'param_card.dat')

# %%
RUNS = 10
for n in range(RUNS):
    qs.generate_LHE(card, FRAMEWORK_PATH)

# %%
LHEs = qs.get_LHEs(FRAMEWORK_PATH)
LHEs
# Out:
# [PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_01/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_05/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_03/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_04/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_09/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_07/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_08/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_06/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_02/unweighted_events.lhe'),
#  PosixPath('/home/leo/MadStats/mg5qs/output/NO_DIRECT_TAU/Events/run_10/unweighted_events.lhe')]

# %%
output_dir = Path('NO_DIRECT_TAUS')  # output path relative to Jupyter
cpu_cores = 10                        # set an appropriate value based on CPU hardware

TAU = 15 # Particle ID for Tau
LHEs = qs.get_LHEs(FRAMEWORK_PATH)

# clear or create output path
if os.path.isdir(output_dir):
    for fname in os.listdir(output_dir):
        if 'pkl' in fname:
            os.remove(output_dir / fname)
else:
    os.mkdir(output_dir)

# function to process a single LHE file, storing result in a pickle file
def process_LHE(n, LHE, PID):
    pTs = qs.generate_pT(PID, LHE)
    params = qs.get_run_params(LHE)
    fname = FRAMEWORK_PATH.name + 'NOTAU.' + str(n) + '.pkl'
    with open(output_dir / fname, 'wb') as f:
        pickle.dump((params, pTs), f)
        f.close()

# run multiple processes in parallel
with concurrent.futures.ProcessPoolExecutor(max_workers=cpu_cores) as executor:
    futures = {executor.submit(process_LHE, i, LHE, TAU): i for i, LHE in enumerate(LHEs)}
# Out:
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.311      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change:  8 Mar 2024  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 12 Jan 2025 at 18:46:13    |  |
#  |  |                                                                              |  |
# ...

# %% [markdown]
# Before loading the transverse momenta, I should note that grep did not find any taus in the .lhe files. So the reduction after cut is trival, 0/0.

# %%
no_direct_taus = qs.unpickle_pTs('/home/leo/MadStats/mg5qs/notebook/NO_DIRECT_TAUS')

# %%
plt.hist(no_direct_taus[1])
plt.yscale('log')
plt.show()

# %%
no_direct_taus[1].max(), no_direct_taus[1].min()
# Out:
# (np.float64(54.44700462609224), np.float64(0.1044889720488885))

# %%
no_direct_taus[1].shape
# Out:
# (948,)

# %%
1000/100_000
# Out:
# 0.01

# %% [markdown]
# The background is roughly 1%, which **must** come from the non-colided haydrons. This is not the expected 40%.

# %%
import pyhepmc

# %%
mg5_shower = Path('/home/leo/MadStats/MadGraph2/mg5amcnlo/NO_DIRECT_TAU/Events/run_04/tag_1_pythia8_events.hepmc.gz')

# %%
count = 0 
with pyhepmc.open(mg5_shower, "r") as reader:
    for event in reader:
        tau_particles = [p for p in event.particles if abs(p.pid) == 15]
        count += len(tau_particles)
        '''
        for tau in tau_particles:
            print(f"Tau found with PDG ID: {tau.pid}")
            print(f"  Status: {tau.status}")
            print(f"  Momentum: px={tau.momentum.px}, py={tau.momentum.py}, pz={tau.momentum.pz}, E={tau.momentum.e}")
        '''

# %%
count
# Out:
# 95

# %% [markdown]
# This matches the above finding sence we ran 10x fewer events for this one .hepmc file.
